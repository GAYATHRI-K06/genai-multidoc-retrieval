# %% [markdown]
# # Lesson 4: Building a Multi-Document Agent

# %% [markdown]
# ## Setup

# %%
from helper import get_openai_api_key
OPENAI_API_KEY = get_openai_api_key()

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## 1. Setup an agent over 3 papers

# %% [markdown]
# **Note**: The pdf files are included with this lesson. To access these papers, go to the `File` menu and select`Open...`.

# %%
urls = [
    "https://openreview.net/pdf?id=VtmBAGCN7o",
    "https://openreview.net/pdf?id=6PmJoRfdaK",
    "https://openreview.net/pdf?id=hSyW5go0v8",
]

papers = [
    "AIeffectiveness.pdf",
    "foundationofai.pdf",
    "learningwithai.pdf",
]

# %%
from utils import get_doc_tools
from pathlib import Path

paper_to_tools_dict = {}
for paper in papers:
    print(f"Getting tools for paper: {paper}")
    vector_tool, summary_tool = get_doc_tools(paper, Path(paper).stem)
    paper_to_tools_dict[paper] = [vector_tool, summary_tool]
# Out:
# Getting tools for paper: AIeffectiveness.pdf
# Getting tools for paper: foundationofai.pdf
# Getting tools for paper: learningwithai.pdf

# %%
initial_tools = [t for paper in papers for t in paper_to_tools_dict[paper]]

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-3.5-turbo")

# %%
len(initial_tools)
# Out:
# 6

# %%
from llama_index.core.agent import FunctionCallingAgentWorker
from llama_index.core.agent import AgentRunner

agent_worker = FunctionCallingAgentWorker.from_tools(
    initial_tools, 
    llm=llm, 
    verbose=True
)
agent = AgentRunner(agent_worker)

# %%
response = agent.query("Give me a summary of AIeffectiveness document")
print(str(response))
# Out:
# Added user message to memory: Give me a summary of AIeffectiveness document
# === Calling Function ===
# Calling function: summary_tool_AIeffectiveness with args: {"input": "summary"}
# === Function Output ===
# Evaluate the Positive LTL by checking if it accurately captures the sequence of milestones. Determine if any errors are present and classify them as either a complete logic failure (LOGIC ERROR) or a skip of steps (MISSING INFO). Then, assess each Negative LTL formula individually by matching it with the corresponding bad behavior from the analysis. Judge if the formula faithfully represents the bad behavior type and content. If it is not faithful, decide if it would punish valid actions (HARMFUL) or if it is simply a broken or useless formula (INEFFECTIVE). Return the evaluation results in a JSON object following the specified structure.
# === LLM Response ===
# The summary of the AIeffectiveness document involves evaluating Positive LTL and Negative LTL formulas to determine if they accurately capture milestones and bad behaviors, respectively. Positive LTL formulas are checked for logic errors or missing information, while Negative LTL formulas are matched with corresponding bad behaviors to assess their faithfulness. The evaluation results are returned in a JSON object following a specified structure.
# assistant: The summary of the AIeffectiveness document involves evaluating Positive LTL and Negative LTL formulas to determine if they accurately capture milestones and bad behaviors, respectively. Positive LTL formulas are checked for logic errors or missing information, while Negative LTL formulas are matched with corresponding bad behaviors to assess their faithfulness. The evaluation results are returned in a JSON object following a specified structure.

# %%
response = agent.query("Give me a summary of foundationofai and learningwithai document")
print(str(response))
# Out:
# Added user message to memory: Give me a summary of foundationofai and learningwithai document
# === Calling Function ===
# Calling function: summary_tool_foundationofai with args: {"input": "summary"}
# === Function Output ===
# The summary captures essential information from various sources, focusing on the development and applications of order-equivariant neural networks (OENN) and category-equivariant neural networks (CENN) in deep learning. It discusses the construction, properties, and universality of OENN layers, emphasizing their effectiveness in structured domains and their ability to handle symmetries and transformations. The relationship between OENN and CENN is explored, showcasing how OENN primitives can be represented by finite CENN primitives. The summary also delves into the Grothendieck Equivariant Net (GroEN) architecture, highlighting its features such as transporting sensor vectors, constructing rotation-invariant channels, and utilizing Transformer encoders for classification tasks. The proofs provided in the text cover various propositions, lemmas, and theorems related to equivariant deep learning and neural network approximations.
# === Calling Function ===
# Calling function: summary_tool_learningwithai with args: {"input": "summary"}
# === Function Output ===
# The text discusses a novel framework called Robust Fuzzy Cross-Modal Hashing (RFCMH) designed to address noisy labels in cross-modal retrieval. RFCMH leverages fuzzy set theory to refine supervision signals and improve representation learning. It consists of two stages: warm-up and fine-tuning, incorporating components like Fuzzy Admissibility Refinement (FAR) and Dual-Granularity Structural Alignment (DGSA). The method aims to overcome performance degradation caused by noise interference and has shown superior robustness in experiments compared to existing methods. Experimental evaluations demonstrate the stability and effectiveness of RFCMH in extracting reliable supervisory signals from noisy annotations while ensuring stable data alignment.
# === LLM Response ===
# The summary of the "foundationofai" document focuses on the development and applications of order-equivariant neural networks (OENN) and category-equivariant neural networks (CENN) in deep learning. It discusses the construction, properties, and universality of OENN layers, emphasizing their effectiveness in structured domains and their ability to handle symmetries and transformations. The relationship between OENN and CENN is explored, showcasing how OENN primitives can be represented by finite CENN primitives. The summary also delves into the Grothendieck Equivariant Net (GroEN) architecture, highlighting its features such as transporting sensor vectors, constructing rotation-invariant channels, and utilizing Transformer encoders for classification tasks. The text provides proofs for various propositions, lemmas, and theorems related to equivariant deep learning and neural network approximations.
#
# The summary of the "learningwithai" document discusses a novel framework called Robust Fuzzy Cross-Modal Hashing (RFCMH) designed to address noisy labels in cross-modal retrieval. RFCMH leverages fuzzy set theory to refine supervision signals and improve representation learning. It consists of two stages: warm-up and fine-tuning, incorporating components like Fuzzy Admissibility Refinement (FAR) and Dual-Granularity Structural Alignment (DGSA). The method aims to overcome performance degradation caused by noise interference and has shown superior robustness in experiments compared to existing methods. Experimental evaluations demonstrate the stability and effectiveness of RFCMH in extracting reliable supervisory signals from noisy annotations while ensuring stable data alignment.
# assistant: The summary of the "foundationofai" document focuses on the development and applications of order-equivariant neural networks (OENN) and category-equivariant neural networks (CENN) in deep learning. It discusses the construction, properties, and universality of OENN layers, emphasizing their effectiveness in structured domains and their ability to handle symmetries and transformations. The relationship between OENN and CENN is explored, showcasing how OENN primitives can be represented by finite CENN primitives. The summary also delves into the Grothendieck Equivariant Net (GroEN) architecture, highlighting its features such as transporting sensor vectors, constructing rotation-invariant channels, and utilizing Transformer encoders for classification tasks. The text provides proofs for various propositions, lemmas, and theorems related to equivariant deep learning and neural network approximations.
#
# The summary of the "learningwithai" document discusses a novel framework called Robust Fuzzy Cross-Modal Hashing (RFCMH) designed to address noisy labels in cross-modal retrieval. RFCMH leverages fuzzy set theory to refine supervision signals and improve representation learning. It consists of two stages: warm-up and fine-tuning, incorporating components like Fuzzy Admissibility Refinement (FAR) and Dual-Granularity Structural Alignment (DGSA). The method aims to overcome performance degradation caused by noise interference and has shown superior robustness in experiments compared to existing methods. Experimental evaluations demonstrate the stability and effectiveness of RFCMH in extracting reliable supervisory signals from noisy annotations while ensuring stable data alignment.

# %%
response = agent.query("Tell me what are the major areas focused on foundationofai document")
print(str(response))
# Out:
# Added user message to memory: Tell me what are the major areas focused on foundationofai document
# === Calling Function ===
# Calling function: vector_tool_foundationofai with args: {"query": "major areas focused"}
# === Function Output ===
# The major areas focused in the provided context are equivariant deep learning, neural network architectures, universal approximation for continuous order-equivariant maps, principled methodology for choosing architectures based on task requirements, broader applicability of Order-Equivariant Neural Networks (OENN) to various data sets indexed by cells or regions, and the connection between OENN and Category-Equivariant Neural Networks (CENN) for improving experimental performance in machine learning tasks.
# === LLM Response ===
# The major areas focused in the "foundationofai" document include equivariant deep learning, neural network architectures, universal approximation for continuous order-equivariant maps, principled methodology for choosing architectures based on task requirements, broader applicability of Order-Equivariant Neural Networks (OENN) to various data sets indexed by cells or regions, and the connection between OENN and Category-Equivariant Neural Networks (CENN) for improving experimental performance in machine learning tasks.
# assistant: The major areas focused in the "foundationofai" document include equivariant deep learning, neural network architectures, universal approximation for continuous order-equivariant maps, principled methodology for choosing architectures based on task requirements, broader applicability of Order-Equivariant Neural Networks (OENN) to various data sets indexed by cells or regions, and the connection between OENN and Category-Equivariant Neural Networks (CENN) for improving experimental performance in machine learning tasks.
